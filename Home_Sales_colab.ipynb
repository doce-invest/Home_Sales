# %%
import os
# Find the latest version of spark 3.x  from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.4.0'
spark_version = 'spark-3.5.1'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop3.tgz
# !tar xf $SPARK_VERSION-bin-hadoop3.tgz
# !pip install -q findspark

# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop3"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done

# %%
# Import packages
from pyspark.sql import SparkSession
import time

# Create a SparkSession
spark = SparkSession.builder.appName("SparkSQL").getOrCreate()

# %%
# 1. Read in the AWS S3 bucket into a DataFrame.
from pyspark import SparkFiles
url = "https://2u-data-curriculum-team.s3.amazonaws.com/dataviz-classroom/v1.2/22-big-data/home_sales_revised.csv"
spark.sparkContext.addFile(url)
df = spark.read.csv(SparkFiles.get("home_sales_revised.csv"), sep=",", header=True)
# Show DataFrame
df.show()
# Out:
# +--------------------+----------+----------+------+--------+---------+-----------+--------+------+----------+----+
# |                  id|      date|date_built| price|bedrooms|bathrooms|sqft_living|sqft_lot|floors|waterfront|view|
# +--------------------+----------+----------+------+--------+---------+-----------+--------+------+----------+----+
# |f8a53099-ba1c-47d...|2022-04-08|      2016|936923|       4|        3|       3167|   11733|     2|         1|  76|
# |7530a2d8-1ae3-451...|2021-06-13|      2013|379628|       2|        2|       2235|   14384|     1|         0|  23|
# |43de979c-0bf0-4c9...|2019-04-12|      2014|417866|       2|        2|       2127|   10575|     2|         0|   0|
# |b672c137-b88c-48b...|2019-10-16|      2016|239895|       2|        2|       1631|   11149|     2|         0|   0|
# |e0726d4d-d595-407...|2022-01-08|      2017|424418|       3|        2|       2249|   13878|     2|         0|   4|
# |5aa00529-0533-46b...|2019-01-30|      2017|218712|       2|        3|       1965|   14375|     2|         0|   7|
# |131492a1-72e2-4a8...|2020-02-08|      2017|419199|       2|        3|       2062|    8876|     2|         0|   6|
# |8d54a71b-c520-44e...|2019-07-21|      2010|323956|       2|        3|       1506|   11816|     1|         0|  25|
# |e81aacfe-17fe-46b...|2020-06-16|      2016|181925|       3|        3|       2137|   11709|     2|         0|  22|
# |2ed8d509-7372-46d...|2021-08-06|      2015|258710|       3|        3|       1918|    9666|     1|         0|  25|
# |f876d86f-3c9f-42b...|2019-02-27|      2011|167864|       3|        3|       2471|   13924|     2|         0|  15|
# |0a2bd445-8508-4d8...|2021-12-30|      2014|337527|       2|        3|       1926|   12556|     1|         0|  23|
# |941bad30-eb49-4a7...|2020-05-09|      2015|229896|       3|        3|       2197|    8641|     1|         0|   3|
# |dd61eb34-6589-4c0...|2021-07-25|      2016|210247|       3|        2|       1672|   11986|     2|         0|  28|
# |f1e4cef7-d151-439...|2019-02-01|      2011|398667|       2|        3|       2331|   11356|     1|         0|   7|
# |ea620c7b-c2f7-4c6...|2021-05-31|      2011|437958|       3|        3|       2356|   11052|     1|         0|  26|
# |f233cb41-6f33-4b0...|2021-07-18|      2016|437375|       4|        3|       1704|   11721|     2|         0|  34|
# |c797ca12-52cd-4b1...|2019-06-08|      2015|288650|       2|        3|       2100|   10419|     2|         0|   7|
# |0cfe57f3-28c2-472...|2019-10-04|      2015|308313|       3|        3|       1960|    9453|     2|         0|   2|
# |4566cd2a-ac6e-435...|2019-07-15|      2016|177541|       3|        3|       2130|   10517|     2|         0|  25|
# +--------------------+----------+----------+------+--------+---------+-----------+--------+------+----------+----+
# only showing top 20 rows

# %%
# 2. Create a temporary view of the DataFrame.

df.createOrReplaceTempView('home_sales')

# %%
# 3. What is the average price for a four bedroom house sold per year, rounded to two decimal places?
query = """
SELECT date_built, ROUND(AVG(Price), 2) as AvgPrice
FROM home_sales
WHERE Bedrooms = '4'
GROUP BY date_built
ORDER BY date_built
"""
spark.sql(query).show()
# Out:
# +----------+---------+
# |date_built| AvgPrice|
# +----------+---------+
# |      2010|296800.75|
# |      2011| 302141.9|
# |      2012|298233.42|
# |      2013|299999.39|
# |      2014|299073.89|
# |      2015|307908.86|
# |      2016|296050.24|
# |      2017|296576.69|
# +----------+---------+

# %%
# 4. What is the average price of a home for each year the home was built,
# that have 3 bedrooms and 3 bathrooms, rounded to two decimal places?
query2 = """
SELECT date_built, ROUND(AVG(Price), 2) as AvgPrice
FROM home_sales
WHERE Bedrooms = '3' AND Bathrooms = '3'
GROUP BY date_built
ORDER BY date_built
"""
spark.sql(query2).show()
# Out:
# +----------+---------+
# |date_built| AvgPrice|
# +----------+---------+
# |      2010|292859.62|
# |      2011|291117.47|
# |      2012|293683.19|
# |      2013|295962.27|
# |      2014|290852.27|
# |      2015| 288770.3|
# |      2016|290555.07|
# |      2017|292676.79|
# +----------+---------+

# %%
# 5. What is the average price of a home for each year the home was built,
# that have 3 bedrooms, 3 bathrooms, with two floors,
# and are greater than or equal to 2,000 square feet, rounded to two decimal places?
query3 = """
SELECT date_built, ROUND(AVG(Price), 2) as AvgPrice
FROM home_sales
WHERE Bedrooms = '3' AND Bathrooms = '3' AND Floors = '2' AND sqft_living >= 2000
GROUP BY date_built
ORDER BY date_built
"""
spark.sql(query3).show()
# Out:
# +----------+---------+
# |date_built| AvgPrice|
# +----------+---------+
# |      2010|285010.22|
# |      2011|276553.81|
# |      2012|307539.97|
# |      2013|303676.79|
# |      2014|298264.72|
# |      2015|297609.97|
# |      2016| 293965.1|
# |      2017|280317.58|
# +----------+---------+

# %%
# 6. What is the average price of a home per "view" rating, rounded to two decimal places,
# having an average home price greater than or equal to $350,000? Order by descending view rating.
# Although this is a small dataset, determine the run time for this query.
query4 = """
SELECT View, ROUND(AVG(Price), 2) as AvgPrice
FROM home_sales
GROUP BY View
HAVING AVG(Price) >= 350000
ORDER BY View DESC
"""
import time
start_time = time.time()



print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.00012135505676269531 seconds ---

# %%
# 7. Cache the the temporary table home_sales.
spark.sql("CACHE TABLE home_sales")
# Out:
# DataFrame[]

# %%
# 8. Check if the table is cached.
spark.sql("EXPLAIN EXTENDED SELECT * FROM home_sales").show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |plan                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |== Parsed Logical Plan ==\n'Project [*]\n+- 'UnresolvedRelation [home_sales], [], false\n\n== Analyzed Logical Plan ==\nid: string, date: string, date_built: string, price: string, bedrooms: string, bathrooms: string, sqft_living: string, sqft_lot: string, floors: string, waterfront: string, view: string\nProject [id#17, date#18, date_built#19, price#20, bedrooms#21, bathrooms#22, sqft_living#23, sqft_lot#24, floors#25, waterfront#26, view#27]\n+- SubqueryAlias home_sales\n   +- View (`home_sales`, [id#17,date#18,date_built#19,price#20,bedrooms#21,bathrooms#22,sqft_living#23,sqft_lot#24,floors#25,waterfront#26,view#27])\n      +- Relation [id#17,date#18,date_built#19,price#20,bedrooms#21,bathrooms#22,sqft_living#23,sqft_lot#24,floors#25,waterfront#26,view#27] csv\n\n== Optimized Logical Plan ==\nInMemoryRelation [id#17, date#18, date_built#19, price#20, bedrooms#21, bathrooms#22, sqft_living#23, sqft_lot#24, floors#25, waterfront#26, view#27], StorageLevel(disk, memory, deserialized, 1 replicas)\n   +- FileScan csv [id#17,date#18,date_built#19,price#20,bedrooms#21,bathrooms#22,sqft_living#23,sqft_lot#24,floors#25,waterfront#26,view#27] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/spark-5370a85d-d20c-4724-a656-5501ff3846ca/userFiles-f65fc38..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:string,date:string,date_built:string,price:string,bedrooms:string,bathrooms:string,sqft...\n\n== Physical Plan ==\nAdaptiveSparkPlan isFinalPlan=false\n+- Scan In-memory table home_sales [id#17, date#18, date_built#19, price#20, bedrooms#21, bathrooms#22, sqft_living#23, sqft_lot#24, floors#25, waterfront#26, view#27]\n      +- InMemoryRelation [id#17, date#18, date_built#19, price#20, bedrooms#21, bathrooms#22, sqft_living#23, sqft_lot#24, floors#25, waterfront#26, view#27], StorageLevel(disk, memory, deserialized, 1 replicas)\n            +- FileScan csv [id#17,date#18,date_built#19,price#20,bedrooms#21,bathrooms#22,sqft_living#23,sqft_lot#24,floors#25,waterfront#26,view#27] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/spark-5370a85d-d20c-4724-a656-5501ff3846ca/userFiles-f65fc38..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:string,date:string,date_built:string,price:string,bedrooms:string,bathrooms:string,sqft...\n|
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# 9. Using the cached data, run the last query above, that calculates
# the average price of a home per "view" rating, rounded to two decimal places,
# having an average home price greater than or equal to $350,000.
# Determine the runtime and compare it to the uncached runtime.
query5 = """
SELECT View, ROUND(AVG(Price), 2) as AvgPrice
FROM home_sales
GROUP BY View
HAVING AVG(Price) >= 350000
ORDER BY View DESC
"""
start_time = time.time()



print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 7.581710815429688e-05 seconds ---

# %%
# 10. Partition by the "date_built" field on the formatted parquet home sales data
output_path = ".../home_sales_partitioned"
df.write.partitionBy("date_built").parquet(output_path)

# %%
# 11. Read the parquet formatted data.
parquet_path = ".../home_sales_partitioned"
parquet_df = spark.read.parquet(parquet_path)

# %%
# 12. Create a temporary table for the parquet data.
parquet_df.createOrReplaceTempView("home_sales_parquet")

# %%
# 13. Using the parquet DataFrame, run the last query above, that calculates
# the average price of a home per "view" rating, rounded to two decimal places,
# having an average home price greater than or equal to $350,000.
# Determine the runtime and compare it to the cached runtime.
query6 = """
SELECT View, ROUND(AVG(Price), 2) as AvgPrice
FROM home_sales_parquet
GROUP BY View
HAVING AVG(Price) >= 350000
ORDER BY View DESC
"""

start_time = time.time()
result = spark.sql(query5)
result.show()


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----+----------+
# |View|  AvgPrice|
# +----+----------+
# |  99|1061201.42|
# |  98|1053739.33|
# |  97|1129040.15|
# |  96|1017815.92|
# |  95| 1054325.6|
# |  94| 1033536.2|
# |  93|1026006.06|
# |  92| 970402.55|
# |  91|1137372.73|
# |  90|1062654.16|
# |  89|1107839.15|
# |  88|1031719.35|
# |  87| 1072285.2|
# |  86|1070444.25|
# |  85|1056336.74|
# |  84|1117233.13|
# |  83|1033965.93|
# |  82| 1063498.0|
# |  81|1053472.79|
# |  80| 991767.38|
# +----+----------+
# only showing top 20 rows
#
# --- 0.8890321254730225 seconds ---

# %%
# 14. Uncache the home_sales temporary table.
spark.sql("UNCACHE TABLE home_sales")
# Out:
# DataFrame[]

# %%
# 15. Check if the home_sales is no longer cached
spark.sql("EXPLAIN EXTENDED SELECT * FROM home_sales").show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |plan                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |== Parsed Logical Plan ==\n'Project [*]\n+- 'UnresolvedRelation [home_sales], [], false\n\n== Analyzed Logical Plan ==\nid: string, date: string, date_built: string, price: string, bedrooms: string, bathrooms: string, sqft_living: string, sqft_lot: string, floors: string, waterfront: string, view: string\nProject [id#17, date#18, date_built#19, price#20, bedrooms#21, bathrooms#22, sqft_living#23, sqft_lot#24, floors#25, waterfront#26, view#27]\n+- SubqueryAlias home_sales\n   +- View (`home_sales`, [id#17,date#18,date_built#19,price#20,bedrooms#21,bathrooms#22,sqft_living#23,sqft_lot#24,floors#25,waterfront#26,view#27])\n      +- Relation [id#17,date#18,date_built#19,price#20,bedrooms#21,bathrooms#22,sqft_living#23,sqft_lot#24,floors#25,waterfront#26,view#27] csv\n\n== Optimized Logical Plan ==\nRelation [id#17,date#18,date_built#19,price#20,bedrooms#21,bathrooms#22,sqft_living#23,sqft_lot#24,floors#25,waterfront#26,view#27] csv\n\n== Physical Plan ==\nFileScan csv [id#17,date#18,date_built#19,price#20,bedrooms#21,bathrooms#22,sqft_living#23,sqft_lot#24,floors#25,waterfront#26,view#27] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/spark-5370a85d-d20c-4724-a656-5501ff3846ca/userFiles-f65fc38..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:string,date:string,date_built:string,price:string,bedrooms:string,bathrooms:string,sqft...\n|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
